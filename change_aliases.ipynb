# %%
import pandas as pd

# %%
old_aliases = [
    "glassy_desert",
    "purple_philosophy",
    "liquid_keyboard",
    "transparent_television",
    "silent_thunder",
    "square_melon",
    "orange_calculus",
    "blue_fire",
    "yellow_gravity",
    "pink_history",
    "black_sunlight",
    "brown_music",
    "silver_laughter",
    "copper_sadness",
    "bronze_thought",
    "iron_emotion",
    "wooden_internet",
    "paper_earthquake",
    "stone_perfume",
    "cotton_volcano",
    "silken_sandstorm",
    "woolen_tsunami",
    "plastic_meteor",
    "ceramic_galaxy",
    "metal_dream",
    "digital_ghost",
    "electric_shadow",
    "solar_whisper",
    "lunar_scream",
    "cosmic_silence",
    "galactic_echo",
    "atomic_opinion",
    "quantum_feeling",
    "sad_explosion",
    "angry_rainbow",
    "excited_glacier",
    "calm_tornado",
    "nervous_mountain",
    "bold_puddle",
    "shy_earthquake",
    "proud_pebble",
    "humble_comet",
    "crunchy_water",
    "bubbly_cement",
    "jagged_melody",
    "noisy_void",
    "swift_glacier",
    "slow_lightning",
    "strong_feather",
    "weak_diamond",
    "big_atom",
    "small_galaxy",
    "opaque_mirror",
    "howling_zenith",
    "tall_whisper",
    "wide_line",
    "narrow_ocean",
    "deep_surface",
    "shallow_abyss",
    "rough_silk",
    "smooth_sandpaper",
    "sharp_pillow",
    "dull_laser",
    "bright_shadow",
    "dim_starlight",
    "quick_molasses",
    "sturdy_paper",
    "covert_balloon",
    "rapid_snail",
    "distant_echo",
    "crimson_logic",
    "frozen_fire",
    "boiling_ice",
    "liquid_rock",
    "solid_air",
    "heavy_feather",
    "light_boulder",
    "sweet_vinegar",
    "sour_sugar",
    "loud_silence",
    "quiet_thunder",
    "fast_turtle",
    "wet_desert",
    "dry_ocean",
    "dark_sun",
    "bright_night",
    "soft_diamond",
    "hard_jelly",
    "cold_flame",
    "hot_snow",
    "visible_wind",
    "invisible_rock",
    "gritty_cloud",
    "spicy_snow",
    "fragrant_dirt",
    "gooey_granite",
    "singing_stone",
    "whispering_fire",
    "glowing_mud",
    "triangular_aroma",
    "fluid_brick",
    "stretchy_theorem",
    "oblong_grapefruit",
    "crimson_algebra",
    "aquamarine_combustion",
    "indigo_radiation",
    "violet_inertia",
    "scarlet_chronology",
    "opaque_glass",
    "luminous_abyss",
    "auburn_harmony",
    "tin_joy",
    "aluminum_melancholy",
    "zinc_perception",
    "steel_intuition",
    "concrete_cyberspace",
    "brittle_oasis",
    "granite_fragrance",
    "cardboard_tremor",
    "linen_eruption",
    "velvet_hurricane",
    "denim_avalanche",
    "rubber_asteroid",
    "porcelain_nebula",
    "titanium_phantom",
    "analog_specter",
    "magnetic_murmur",
    "nuclear_hush",
    "stellar_reverberation",
    "planetary_drone",
    "subatomic_hypothesis",
    "virtual_instinct",
    "blissful_void",
    "desolate_fireworks",
    "furious_garden",
    "thrilled_avalanche",
    "serene_wildfire",
    "anxious_boulder",
    "daring_raindrop",
    "timid_volcano",
    "arrogant_grain",
    "modest_supernova",
    "deafening_hush",
    "vocal_vacuum",
    "accelerated_erosion",
    "lethargic_flash",
    "fragile_titanium",
    "robust_gossamer",
    "minuscule_universe",
    "immense_particle",
    "towering_murmur",
    "brief_epic",
    "expansive_crevice",
    "confined_infinity",
    "abyssal_film",
    "superficial_chasm",
    "abrasive_velvet",
    "polished_grit",
    "pointed_foam",
    "blunted_razor",
    "glowing_midnight",
    "darkened_flare",
    "durable_tissue",
    "obvious_enigma",
    "sluggish_geyser",
    "nearby_aberration",
    "scarlet_epistemology",
    "pastoral_metropolis",
    "industrial_wilderness",
    "offshore_peak",
    "frigid_inferno",
    "subzero_sunbeam",
    "gaseous_obsidian",
    "ethereal_lead",
    "weightless_granite",
    "buoyant_anchor",
    "bitter_nectar",
    "alkaline_honey",
    "thundering_whisper",
    "muffled_blast",
    "expedient_snail",
    "dilatory_bullet",
    "elevated_trench",
    "sunken_plateau",
    "arid_swamp",
    "saturated_dune",
]

new_aliases = [
    "sculpted_antelope",
    "miniature_bass",
    "triangular_cobra",
    "flexible_dragonfly",
    "transparent_eagle",
    "silent_fox",
    "spherical_goat",
    "goldenrod_herring",
    "chartreuse_iguana",
    "lavender_jackal",
    "maroon_kangaroo",
    "teal_locust",
    "opaque_magpie",
    "glossy_newt",
    "bronze_ocelot",
    "silver_porcupine",
    "wooden_quail",
    "glass_rattlesnake",
    "stone_salmon",
    "paper_termite",
    "cotton_urial",
    "silk_viper",
    "wool_wren",
    "plastic_yak",
    "ceramic_zebu",
    "metal_anchovy",
    "digital_bear",
    "electric_chinchilla",
    "solar_dog",
    "lunar_earwig",
    "cosmic_falcon",
    "galactic_gorilla",
    "atomic_hornet",
    "quantum_ibex",
    "happy_jaguar",
    "sad_kiwi",
    "angry_lemur",
    "excited_manatee",
    "calm_narwhal",
    "nervous_octopus",
    "bold_pheasant",
    "shy_quokka",
    "proud_robin",
    "humble_scorpion",
    "noisy_tapir",
    "quiet_urchin",
    "fast_vole",
    "slow_wombat",
    "strong_xerus",
    "weak_yaksha",
    "big_zebra",
    "small_aardvark",
    "tall_baboon",
    "short_caracal",
    "wide_dingo",
    "narrow_emu",
    "deep_flamingo",
    "shallow_gecko",
    "rough_hirola",
    "smooth_impala",
    "sharp_jellyfish",
    "dull_koala",
    "bright_lizard",
    "dim_mongoose",
    "quick_nematode",
    "sturdy_orca",
    "covert_parrot",
    "rapid_quetzal",
    "distant_rhea",
    "crimson_stingray",
    "urban_tuatara",
    "rural_unicorn",
    "coastal_viperfish",
    "frozen_weasel",
    "boiling_xerus",
    "liquid_yabby",
    "solid_zorilla",
    "heavy_ant",
    "light_boa",
    "sweet_carp",
    "sour_dolphin",
    "loud_eel",
    "soft_firefly",
    "high_gecko",
    "low_haddock",
    "wet_iguana",
    "dry_jellyfish",
    "dark_kudu",
    "soft_lamprey",
    "cold_mole",
    "hot_newt",
    "visible_orca",
    "invisible_parrot",
    "oblong_quetzal",
    "elastic_rhea",
    "immense_sardine",
    "stretchy_tetra",
    "tangible_urchin",
    "sticky_vole",
    "floral_wildebeest",
    "spicy_xantus",
    "frigid_yeti",
    "pliable_zorse",
    "durable_albatross",
    "fragile_buffalo",
    "obvious_capybara",
    "subtle_dugong",
    "nearby_elephant",
    "remote_ferret",
    "linear_grasshopper",
    "jagged_hermitcrab",
    "vibrant_ibis",
    "faded_jerboa",
    "ancient_kangaroo",
    "modern_lemur",
    "future_mink",
    "past_narwhal",
    "square_okapi",
    "tubular_porpoise",
    "sharp_quail",
    "blunt_rattlesnake",
    "complex_squid",
    "simple_termite",
    "potent_urial",
    "feeble_viper",
    "optimal_wren",
    "inferior_yak",
    "legal_zebu",
    "illegal_adder",
    "parallel_bandicoot",
    "perpendicular_cicada",
    "hollow_donkey",
    "solid_elk",
    "rotating_frog",
    "stationary_gecko",
    "ascending_heron",
    "descending_iguana",
    "primary_jay",
    "secondary_kiwi",
    "north_locust",
    "south_marmot",
    "east_newt",
    "west_ocelot",
    "diagonal_porcupine",
    "broken_quokka",
    "fixed_rooster",
    "infinite_stork",
    "finite_tarantula",
    "elastic_urus",
    "brittle_viperfish",
    "open_whale",
    "closed_xantus",
    "transparent_yak",
    "opaque_zorilla",
    "sizzling_armadillo",
    "frigid_barracuda",
    "slippery_chameleon",
    "rough_dolphin",
    "smooth_egret",
    "granular_falcon",
    "polished_grouse",
    "hairy_herring",
    "bald_iguana",
    "fragrant_jackal",
    "pungent_kangaroo",
    "slippery_locust",
    "gritty_magpie",
    "melodic_newt",
    "cacophonous_ocelot",
    "luminous_parrot",
    "somber_quail",
    "hissing_raccoon",
    "silent_skink",
    "speedy_tapir",
    "sluggish_uakari",
    "potent_viper",
    "pungent_wombat",
    "meager_xantus",
    "plentiful_yabby",
    "gigantic_zorilla",
    "microscopic_anteater",
    "vertical_bobcat",
    "horizontal_catfish",
    "lush_dragon",
    "barren_eagle",
    "curly_falcon",
]

# %%
alias_table = pd.read_csv("figure_aliases.csv").assign(new_alias=new_aliases)
alias_table.to_csv("figure_aliases_updated.csv", index=False)

alias_table.drop(columns=["alias"], inplace=True)
alias_table.rename(columns={"new_alias": "alias"}, inplace=True)

alias_table = alias_table.loc[:,["alias","science_submission","nature_submission","nature_revision"]]
alias_table.to_csv("figure_aliases.csv", index=False)
